# %%
import pandas as pd
import numpy as np
import datetime
import requests
import os.path
import os



from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
dfcovid_ciudades = pd.read_csv(os.path.join('../Output', 'data_final.csv'))
dfcovid_ciudades.head()
# Out:
#    ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA  CIUDAD DE UBICACION  \
# 0           1            2020-03-02            11001          BOGOTA D.C.
# 1           3            2020-03-07             5001             MEDELLIN
# 2           4            2020-03-09             5001             MEDELLIN
# 3           5            2020-03-09             5001             MEDELLIN
# 4           7            2020-03-08            13001  CARTAGENA DE INDIAS
#
#   DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO         TIPO ESTADO  \
# 0              BOGOTA D.C.  RECUPERADO    19    F    IMPORTADO   LEVE
# 1                ANTIOQUIA  RECUPERADO    50    F    IMPORTADO   LEVE
# 2                ANTIOQUIA  RECUPERADO    55    M  RELACIONADO   LEVE
# 3                ANTIOQUIA  RECUPERADO    25    M  RELACIONADO   LEVE
# 4      CARTAGENA D.T. Y C.  RECUPERADO    85    F    IMPORTADO   LEVE
#
#   PAIS DE PROCEDENCIA                      FIS FECHA DE MUERTE  \
# ...

# %%
#DataFrame de la ciudad de Medellín

dfmedellin=dfcovid_ciudades[dfcovid_ciudades['CODIGO DIVIPOLA']==5001]
dfmedellin.head()
# Out:
#     ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA CIUDAD DE UBICACION  \
# 1            3            2020-03-07             5001            MEDELLIN
# 2            4            2020-03-09             5001            MEDELLIN
# 3            5            2020-03-09             5001            MEDELLIN
# 13          20            2020-03-11             5001            MEDELLIN
# 14          21            2020-03-11             5001            MEDELLIN
#
#    DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO         TIPO ESTADO  \
# 1                 ANTIOQUIA  RECUPERADO    50    F    IMPORTADO   LEVE
# 2                 ANTIOQUIA  RECUPERADO    55    M  RELACIONADO   LEVE
# 3                 ANTIOQUIA  RECUPERADO    25    M  RELACIONADO   LEVE
# 13                ANTIOQUIA  RECUPERADO    26    F  RELACIONADO   LEVE
# 14                ANTIOQUIA  RECUPERADO    28    M  RELACIONADO   LEVE
#
#    PAIS DE PROCEDENCIA                      FIS FECHA DE MUERTE  \
# ...

# %%
#DataFrame de la ciudad de Bogotá

dfbogota=dfcovid_ciudades[dfcovid_ciudades['CODIGO DIVIPOLA']==11001]
dfbogota.head()
# Out:
#    ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA CIUDAD DE UBICACION  \
# 0           1            2020-03-02            11001         BOGOTA D.C.
# 5           8            2020-03-09            11001         BOGOTA D.C.
# 6           9            2020-03-08            11001         BOGOTA D.C.
# 7          10            2020-03-12            11001         BOGOTA D.C.
# 8          11            2020-03-11            11001         BOGOTA D.C.
#
#   DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO       TIPO ESTADO  \
# 0              BOGOTA D.C.  RECUPERADO    19    F  IMPORTADO   LEVE
# 5              BOGOTA D.C.  RECUPERADO    22    F  IMPORTADO   LEVE
# 6              BOGOTA D.C.  RECUPERADO    28    F  IMPORTADO   LEVE
# 7              BOGOTA D.C.  RECUPERADO    36    F  IMPORTADO   LEVE
# 8              BOGOTA D.C.  RECUPERADO    42    F  IMPORTADO   LEVE
#
#   PAIS DE PROCEDENCIA                      FIS FECHA DE MUERTE  \
# ...

# %%
#DataFrame de la ciudad de Cali

dfcali=dfcovid_ciudades[dfcovid_ciudades['CODIGO DIVIPOLA']==76001]
dfcali.head()
# Out:
#     ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA CIUDAD DE UBICACION  \
# 17          25            2020-03-13            76001                CALI
# 43          62            2020-03-14            76001                CALI
# 44          63            2020-03-16            76001                CALI
# 55          81            2020-03-17            76001                CALI
# 56          82            2020-03-16            76001                CALI
#
#    DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO       TIPO ESTADO  \
# 17          VALLE DEL CAUCA  RECUPERADO    49    M  IMPORTADO   LEVE
# 43          VALLE DEL CAUCA  RECUPERADO    32    M  IMPORTADO   LEVE
# 44          VALLE DEL CAUCA  RECUPERADO    26    F  IMPORTADO   LEVE
# 55          VALLE DEL CAUCA  RECUPERADO    49    F  IMPORTADO   LEVE
# 56          VALLE DEL CAUCA  RECUPERADO    54    M  IMPORTADO   LEVE
#
#    PAIS DE PROCEDENCIA                      FIS FECHA DE MUERTE  \
# ...

# %%
#DataFrame de la ciudad de Cartagena

dfcartagena=dfcovid_ciudades[dfcovid_ciudades['CODIGO DIVIPOLA']==13001]
dfcartagena.head()
# Out:
#     ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA  CIUDAD DE UBICACION  \
# 4            7            2020-03-08            13001  CARTAGENA DE INDIAS
# 18          26            2020-03-15            13001  CARTAGENA DE INDIAS
# 19          27            2020-03-15            13001  CARTAGENA DE INDIAS
# 40          58            2020-03-13            13001  CARTAGENA DE INDIAS
# 52          73            2020-03-16            13001  CARTAGENA DE INDIAS
#
#    DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO         TIPO        ESTADO  \
# 4       CARTAGENA D.T. Y C.  RECUPERADO    85    F    IMPORTADO          LEVE
# 18      CARTAGENA D.T. Y C.  RECUPERADO    30    F  RELACIONADO  ASINTOMATICO
# 19      CARTAGENA D.T. Y C.  RECUPERADO    30    F  RELACIONADO  ASINTOMATICO
# 40      CARTAGENA D.T. Y C.  RECUPERADO    27    M  RELACIONADO          LEVE
# 52      CARTAGENA D.T. Y C.  RECUPERADO    54    F  RELACIONADO          LEVE
#
# ...

# %%
#DataFrame de la ciudad de Barranquilla

dfbarranquilla=dfcovid_ciudades[dfcovid_ciudades['CODIGO DIVIPOLA']==8001]
dfbarranquilla.head()
# Out:
#     ID DE CASO FECHA DE NOTIFICACION  CODIGO DIVIPOLA CIUDAD DE UBICACION  \
# 41          59            2020-03-14             8001        BARRANQUILLA
# 42          61            2020-03-16             8001        BARRANQUILLA
# 68         104            2020-03-19             8001        BARRANQUILLA
# 81         126            2020-03-18             8001        BARRANQUILLA
# 82         127            2020-03-18             8001        BARRANQUILLA
#
#    DEPARTAMENTO O DISTRITO     ATENCION  EDAD SEXO         TIPO ESTADO  \
# 41        BARRANQUILLA D.E.  RECUPERADO    20    M    IMPORTADO   LEVE
# 42        BARRANQUILLA D.E.  RECUPERADO    21    M    IMPORTADO   LEVE
# 68        BARRANQUILLA D.E.  RECUPERADO    48    F    IMPORTADO   LEVE
# 81        BARRANQUILLA D.E.  RECUPERADO    52    F    IMPORTADO   LEVE
# 82        BARRANQUILLA D.E.  RECUPERADO    30    F  RELACIONADO   LEVE
#
#    PAIS DE PROCEDENCIA                      FIS FECHA DE MUERTE  \
# ...

# %%
#Casos confirmados para Medellín
dfm = pd.to_datetime(dfmedellin['FECHA REPORTE WEB'])
dfmedellin_confirmados = dfm.groupby(dfm.dt.floor('d')).size().reset_index(name='FRECUENCIA')


#Casos confirmados para Bogotá
dfb = pd.to_datetime(dfbogota['FECHA REPORTE WEB'])
dfbogota_confirmados = dfb.groupby(dfb.dt.floor('d')).size().reset_index(name='FRECUENCIA')


#Casos confirmados para Cali
dfc = pd.to_datetime(dfcali['FECHA REPORTE WEB'])
dfcali_confirmados = dfc.groupby(dfc.dt.floor('d')).size().reset_index(name='FRECUENCIA')


#Casos confirmados para Cartagena
dfcart = pd.to_datetime(dfcartagena['FECHA REPORTE WEB'])
dfcartagena_confirmados = dfcart.groupby(dfcart.dt.floor('d')).size().reset_index(name='FRECUENCIA')


#Casos confirmados para Barranquilla
dfbarr = pd.to_datetime(dfbarranquilla['FECHA REPORTE WEB'])
dfbarranquilla_confirmados = dfbarr.groupby(dfbarr.dt.floor('d')).size().reset_index(name='FRECUENCIA')
# Out:
# (156, 2)

# %%
#Clasificación para el DataFrame de casos confirmados de la ciudad de Medellín

from sklearn.model_selection import train_test_split

x = dfmedellin_confirmados.drop(columns = ['FRECUENCIA'])
y = dfmedellin_confirmados['FRECUENCIA']
x_medellin_confirmados_train, x_medellin_confirmados_test, y_medellin_confirmados_train, y_medellin_confirmados_test = train_test_split(x, y, test_size=0.3, random_state=15)
print(x_medellin_confirmados_train.shape)
print(x_medellin_confirmados_test.shape)
# Out:
# (113, 1)
# (49, 1)

# %%
#Clasificación para el DataFrame de casos confirmados de la ciudad de Bogotá

from sklearn.model_selection import train_test_split

x = dfbogota_confirmados.drop(columns = ['FRECUENCIA'])
y = dfbogota_confirmados['FRECUENCIA']
x_bogota_confirmados_train, x_bogota_confirmados_test, y_bogota_confirmados_train, y_bogota_confirmados_test = train_test_split(x, y, test_size=0.3, random_state=15)
print(x_bogota_confirmados_train.shape)
print(x_bogota_confirmados_test.shape)
# Out:
# (119, 1)
# (52, 1)

# %%
#Clasificación para el DataFrame de casos confirmados de la ciudad de Cali

from sklearn.model_selection import train_test_split

x = dfcali_confirmados.drop(columns = ['FRECUENCIA'])
y = dfcali_confirmados['FRECUENCIA']
x_cali_confirmados_train, x_cali_confirmados_test, y_cali_confirmados_train, y_cali_confirmados_test = train_test_split(x, y, test_size=0.3, random_state=15)
print(x_cali_confirmados_train.shape)
print(x_cali_confirmados_test.shape)
# Out:
# (114, 1)
# (49, 1)

# %%
#Clasificación para el DataFrame de casos confirmados de la ciudad de Cartagena

from sklearn.model_selection import train_test_split

x = dfcartagena_confirmados.drop(columns = ['FRECUENCIA'])
y = dfcartagena_confirmados['FRECUENCIA']
x_cartagena_confirmados_train, x_cartagena_confirmados_test, y_cartagena_confirmados_train, y_cartagena_confirmados_test = train_test_split(x, y, test_size=0.3, random_state=15)
print(x_cartagena_confirmados_train.shape)
print(x_cartagena_confirmados_test.shape)
# Out:
# (111, 1)
# (48, 1)

# %%
#Clasificación para el DataFrame de casos confirmados de la ciudad de Barranquilla

from sklearn.model_selection import train_test_split

x = dfbarranquilla_confirmados.drop(columns = ['FRECUENCIA'])
y = dfbarranquilla_confirmados['FRECUENCIA']
x_barranquilla_confirmados_train, x_barranquilla_confirmados_test, y_barranquilla_confirmados_train, y_barranquilla_confirmados_test = train_test_split(x, y, test_size=0.3, random_state=15)
print(x_barranquilla_confirmados_train.shape)
print(x_barranquilla_confirmados_test.shape)
# Out:
# (109, 1)
# (47, 1)

# %%
#Clasificación usando kfold para mayor aleatoriedad para el DataFrame de confirmados de Medellín

from sklearn.model_selection import KFold

kf = KFold(n_splits=3)
for train, test in kf.split(dfmedellin_confirmados):
    print("Indices -- Train: ", train[100:105], " - Test: ", test[50:60]) #Indices
    print("TRAIN")
    print(dfmedellin_confirmados.iloc[train].head().iloc[:,0:3])
    print()
    print("TEST")
    print(dfmedellin_confirmados.iloc[test].head().iloc[:,0:3])
    print()
    print()
# Out:
# Indices -- Train:  [154 155 156 157 158]  - Test:  [50 51 52 53]
# TRAIN
#    FECHA REPORTE WEB  FRECUENCIA
# 54        2020-05-12           4
# 55        2020-05-13           7
# 56        2020-05-14          10
# 57        2020-05-15           7
# 58        2020-05-16           6
#
# TEST
#   FECHA REPORTE WEB  FRECUENCIA
# 0        2020-03-09           1
# 1        2020-03-11           2
# 2        2020-03-14           2
# 3        2020-03-15           1
# 4        2020-03-19           3
#
#
# Indices -- Train:  [154 155 156 157 158]  - Test:  [104 105 106 107]
# TRAIN
#   FECHA REPORTE WEB  FRECUENCIA
# 0        2020-03-09           1
# 1        2020-03-11           2
# 2        2020-03-14           2
# 3        2020-03-15           1
# 4        2020-03-19           3
#
# TEST
#    FECHA REPORTE WEB  FRECUENCIA
# 54        2020-05-12           4
# 55        2020-05-13           7
# 56        2020-05-14          10
# 57        2020-05-15           7
# ...

# %%
print(y_medellin_confirmados_test)
# Out:
# 154     424
# 30        6
# 116     228
# 92       92
# 26       10
# 135    1580
# 100     132
# 72       16
# 148    1031
# 110     240
# 9         6
# 65       34
# 111     233
# 131     674
# 142     901
# 123     691
# 139     821
# 98       95
# 121     887
# 6         1
# 159     613
# 134    1106
# 146     956
# 59        8
# 153     973
# 25        7
# 31        8
# 89       35
# 61       13
# 120     599
# 55        7
# 63       13
# 57        7
# 40        8
# 58        6
# 138     653
# 149     999
# 48        3
# 5         7
# 68       23
# 113     407
# 0         1
# 78       13
# 47        3
# 20       13
# 80       16
# 27       13
# 74        5
# 3         1
# Name: FRECUENCIA, dtype: int64

# %%
len(dfmedellin_confirmados)
# Out:
# 162

# %%
population = float(100000)
country_df = dfmedellin_confirmados
country_df['ConfirmedCases'] = x_medellin_confirmados_train.loc[x_medellin_confirmados_train['']=='MEDELLIN'].ConfirmedCases.diff().fillna(0)
country_df = country_df[10:]
country_df['day_count'] = list(range(1,len(country_df)+1))

ydata = [i for i in country_df.ConfirmedCases]
xdata = country_df.day_count
ydata = np.array(ydata, dtype=float)
xdata = np.array(xdata, dtype=float)

N = population
inf0 = ydata[0]
sus0 = N - inf0
rec0 = 0.0

def sir_model(y, x, beta, gamma):
    sus = -beta * y[0] * y[1] / N
    rec = gamma * y[1]
    inf = -(sus + rec)
    return sus, inf, rec

def fit_odeint(x, beta, gamma):
    return integrate.odeint(sir_model, (sus0, inf0, rec0), x, args=(beta, gamma))[:,1]

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)

plt.plot(xdata, ydata, 'o')
plt.plot(xdata, fitted)
plt.title("Fit of SIR model for Spain infected cases")
plt.ylabel("Population infected")
plt.xlabel("Days")
plt.show()
print("Optimal parameters: beta =", popt[0], " and gamma = ", popt[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-a4830bc86a2d> in <module>
#       1 population = float(100000)
# ...

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = len(dfmedellin_confirmados)
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.2, 1./10 
# A grid of time points (in days)
t = np.linspace(0,160,160)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S/len(dfmedellin_confirmados), 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/len(dfmedellin_confirmados), 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/len(dfmedellin_confirmados), 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-305-9ecfc41fe3f5> in <module>
#      25 y0 = S0, I0, R0
#      26 # Integrate the SIR equations over the time grid, t.
# ---> 27 ret = odeint(deriv, y0, t, args=(N, beta, gamma))
#      28 S, I, R = ret.T
#      29
#
# ~\anaconda3\lib\site-packages\scipy\integrate\odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     243                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 245                              int(bool(tfirst)))
#     246     if output[-1] < 0:
#     247         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# ...
