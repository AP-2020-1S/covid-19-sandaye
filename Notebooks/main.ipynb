# %%
# %run ./1.down_data.ipynb

# %%
# %run ./2.Clear_data.ipynb
# Out:
# Requirement already satisfied: unidecode in c:\users\yaflo\anaconda3\lib\site-packages (1.1.1)
# C:\Users\yaflo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10,14,16,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# %run ./3.dataframe_ciudades.ipynb
# Out:
# C:\Users\yaflo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (12,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#%run ./4.Modelo_SIR.ipynb

# %%
#%run ./6.Auto-arima.ipynb

# %%
#%run ./predict_cortoplazo.ipynb
