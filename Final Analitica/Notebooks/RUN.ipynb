# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
# %run ./1.down_data.ipynb

# %%
# %run ./2.Clear_data.ipynb

# %%
# %run ./3.dataframe_ciudades.ipynb

# %%
# %run ./4.muestras_procesadas.ipynb

# %%
# %run ./5.medellin_corto.ipynb

# %%
# %run ./6.bogota_corto.ipynb

# %%
# %run ./7.cali_corto.ipynb

# %%
# %run ./8.barranquilla_corto.ipynb

# %%
# %run ./9.cartagena_corto.ipynb

# %%
# %run ./10.medellin_SIR_mediano.ipynb

# %%
# %run ./11.bogota_SIR_mediano.ipynb

# %%
# %run ./12.cali_SIR_mediano.ipynb

# %%
# %run ./13.barranquilla_SIR_mediano.ipynb

# %%
14.cartagena_SIR_mediano.ipynb
