# %%
# %run ./1.down_data.ipynb

# %%
# %run ./2.Clear_data.ipynb
# Out:
# ...
# /home/oem/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py in __call__(self, coro)
#      26         import asyncio
#      27
# ---> 28         return asyncio.get_event_loop().run_until_complete(coro)
#      29
#      30     def __str__(self):
#
# ~/anaconda3/lib/python3.8/asyncio/base_events.py in run_until_complete(self, future)
#     590         """
#     591         self._check_closed()
# --> 592         self._check_running()
#     593
#     594         new_task = not futures.isfuture(future)
#
# ...

# %%
# %run ./3.dataframe_ciudades.ipynb

# %%
#%run ./4.Modelo_SIR.ipynb

# %%
#%run ./5.Modelo_corto_medellin.ipynb

# %%
#%run ./predict_cortoplazo.ipynb
